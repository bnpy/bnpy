# %%
import bnpy
import numpy as np
import util

from matplotlib import pyplot as plt

# %%
alloc_model = 'FiniteHMM'
obs_model = 'DiagGauss'
learn_alg = 'VB'
out_path = 'experiments/grid'
dataset_title = 'Grid toy data'

# %% [markdown]
# To plot previously saved experimental results, skip to **Plot Results** section directly.

# %% [markdown]
# # Generate data

# %%
N, T, D = 200, 20, 2
n_rows, n_cols = 3, 3
K = n_rows * n_cols
dataset = util.generate_grid_data(N, T, n_rows, n_cols)

# %% [markdown]
# # Visualize data

# %%
plt.scatter(dataset.X[:, 0], dataset.X[:, 1], c=dataset.TrueParams['Z'])
plt.show()

# %% [markdown]
# # Run experiments

# %%
experiment = util.run_experiment(dataset, alloc_model, obs_model, learn_alg, K, out_path)

# %% [markdown]
# # Plot results

# %%
# Load results if necessary
try:
    experiment
except NameError:
    experiment = util.load_experiment(out_path)

# %%
dataset = experiment[0][1]['Data']
plt.scatter(dataset.X[:, 0], dataset.X[:, 1], c=dataset.TrueParams['Z'])
plt.title('Grid toy data - Observations')
plt.show()

# %%
util.plot_loss(experiment, dataset_title, ymax=3.46)

# %%
util.plot_hamming(experiment, dataset_title, ymax=0.32)

# %%
util.plot_clusters(experiment, dataset_title)

# %%
experiment[0][1]['Data']
