# %%
import bnpy
import numpy as np
import util

# %%
alloc_model = 'FiniteHMM'
obs_model = 'AutoRegGauss'
learn_alg = 'VB'
out_path = 'experiments/mocap-newargs'
dataset_title = 'MoCap6'

# %% [markdown]
# # Load data

# %%
dataset = util.load_mocap_data()

# %% [markdown]
# # Run experiment

# %%
K = 20
kwargs = {
    'ECovMat': 'diagcovfirstdiff',
    'sF': 0.5,
    'VMat': 'same',
    'sV': 0.5,
    'MMat': 'eye'
}

experiment = util.run_experiment(dataset, alloc_model, obs_model, learn_alg, K, out_path, **kwargs)
# Out:
# Training dense model
# Dataset Summary:
# GroupXData
#   size: 6 units (documents)
#   dimension: 12
# Allocation Model:  None
# Obs. Data  Model:  Auto-Regressive Gaussian with full covariance.
# Obs. Data  Prior:  MatrixNormal-Wishart on each mean/prec matrix pair: A, Lam
#   E[ A ] =
#   [[ 1.  0.]
#    [ 0.  1.]] ...
#   E[ Sigma ] =
#   [[ 0.14990727  0.        ]
#    [ 0.          3.65403627]] ...
# Initialization:
#   initname = randexamples
#   K = 20 (number of clusters)
#   seed = 1607680
#   elapsed_time: 0.0 sec
# Learn Alg: VB | task  1/5 | alg. seed: 1607680 | data order seed: 8541952
# task_output_path: experiments/mocap-newargs/dense/1
#         1/500 after      0 sec. |    129.5 MiB | K   20 | loss  2.632934182e+00 |
#         2/500 after      0 sec. |    129.9 MiB | K   20 | loss  2.395465918e+00 | Ndiff   61.088
#        25/500 after      3 sec. |    130.4 MiB | K   20 | loss  2.221555057e+00 | Ndiff    1.647
#        50/500 after      6 sec. |    130.8 MiB | K   20 | loss  2.219130524e+00 | Ndiff    0.035
#        75/500 after      9 sec. |    130.8 MiB | K   20 | loss  2.217803019e+00 | Ndiff    0.079
#        97/500 after     11 sec. |    130.8 MiB | K   20 | loss  2.217766541e+00 | Ndiff    0.000
# ... done. converged.
# Learn Alg: VB | task  2/5 | alg. seed: 6454144 | data order seed: 7673856
# task_output_path: experiments/mocap-newargs/dense/2
#         1/500 after      0 sec. |    138.1 MiB | K   20 | loss  2.727537638e+00 |
#         2/500 after      0 sec. |    137.8 MiB | K   20 | loss  2.510919867e+00 | Ndiff   99.631
#        25/500 after      3 sec. |    138.0 MiB | K   20 | loss  2.241191522e+00 | Ndiff    1.272
#        50/500 after      6 sec. |    138.1 MiB | K   20 | loss  2.239448028e+00 | Ndiff    0.018
#        59/500 after      7 sec. |    138.1 MiB | K   20 | loss  2.239448003e+00 | Ndiff    0.000
# ... done. converged.
# Learn Alg: VB | task  3/5 | alg. seed: 6168832 | data order seed: 7360256
# task_output_path: experiments/mocap-newargs/dense/3
#         1/500 after      0 sec. |    145.4 MiB | K   20 | loss  2.707747109e+00 |
#         2/500 after      0 sec. |    145.4 MiB | K   20 | loss  2.468381930e+00 | Ndiff   82.473
#        25/500 after      3 sec. |    145.6 MiB | K   20 | loss  2.211192211e+00 | Ndiff    1.001
#        50/500 after      6 sec. |    145.6 MiB | K   20 | loss  2.209443347e+00 | Ndiff    0.042
#        75/500 after      9 sec. |    145.6 MiB | K   20 | loss  2.207772028e+00 | Ndiff    1.387
#        87/500 after     10 sec. |    145.8 MiB | K   20 | loss  2.206136977e+00 | Ndiff    0.000
# ... done. converged.
# Learn Alg: VB | task  4/5 | alg. seed: 8205184 | data order seed: 900864
# task_output_path: experiments/mocap-newargs/dense/4
#         1/500 after      0 sec. |    138.9 MiB | K   20 | loss  2.700731184e+00 |
#         2/500 after      0 sec. |    138.9 MiB | K   20 | loss  2.481778394e+00 | Ndiff   48.008
#        25/500 after      3 sec. |    138.9 MiB | K   20 | loss  2.245183839e+00 | Ndiff    0.616
#        50/500 after      6 sec. |    138.9 MiB | K   20 | loss  2.244076954e+00 | Ndiff    0.169
#        75/500 after      9 sec. |    138.9 MiB | K   20 | loss  2.237896796e+00 | Ndiff    0.328
#       100/500 after     12 sec. |    138.9 MiB | K   20 | loss  2.237561583e+00 | Ndiff    0.002
#       106/500 after     12 sec. |    138.9 MiB | K   20 | loss  2.237561583e+00 | Ndiff    0.000
# ... done. converged.
# Learn Alg: VB | task  5/5 | alg. seed: 2986368 | data order seed: 6479872
# task_output_path: experiments/mocap-newargs/dense/5
#         1/500 after      0 sec. |    146.1 MiB | K   20 | loss  2.728359460e+00 |
#         2/500 after      0 sec. |    145.8 MiB | K   20 | loss  2.484677926e+00 | Ndiff  101.160
#        25/500 after      3 sec. |    145.9 MiB | K   20 | loss  2.228782114e+00 | Ndiff    3.525
#        50/500 after      6 sec. |    145.9 MiB | K   20 | loss  2.214276418e+00 | Ndiff    0.026
#        75/500 after      9 sec. |    146.0 MiB | K   20 | loss  2.214270468e+00 | Ndiff    0.000
# ... done. converged.
# Training sparse model L = 1
# Learn Alg: VB | task  3/1 | alg. seed: 6168832 | data order seed: 7360256
# task_output_path: experiments/mocap-newargs/sparse-L=1/3
#         1/500 after      0 sec. |    139.5 MiB | K   20 | loss  2.706284183e+00 |
#         2/500 after      0 sec. |    139.5 MiB | K   20 | loss  2.443163917e+00 | Ndiff   86.000
#        10/500 after      1 sec. |    139.5 MiB | K   20 | loss  2.309956579e+00 | Ndiff    0.000
# ... done. converged.
# Training sparse model L = 2
# Learn Alg: VB | task  3/1 | alg. seed: 6168832 | data order seed: 7360256
# task_output_path: experiments/mocap-newargs/sparse-L=2/3
#         1/500 after      0 sec. |    146.9 MiB | K   20 | loss  2.707734065e+00 |
#         2/500 after      0 sec. |    146.9 MiB | K   20 | loss  2.472908893e+00 | Ndiff   88.973
#        25/500 after      5 sec. |    146.9 MiB | K   20 | loss  2.207461300e+00 | Ndiff    1.376
#        49/500 after      9 sec. |    147.0 MiB | K   20 | loss  2.206871459e+00 | Ndiff    0.000
# ... done. converged.
# Training O(L^2) model L = 2
# Learn Alg: VB | task  3/1 | alg. seed: 6168832 | data order seed: 7360256
# task_output_path: experiments/mocap-newargs/OL2-L=2/3
#         1/500 after      0 sec. |    154.3 MiB | K   20 | loss  2.707734065e+00 |
#         2/500 after      0 sec. |    154.0 MiB | K   20 | loss  2.467297644e+00 | Ndiff   90.010
#        25/500 after      5 sec. |    153.9 MiB | K   20 | loss  2.211712403e+00 | Ndiff    0.294
#        43/500 after      9 sec. |    153.9 MiB | K   20 | loss  2.209985843e+00 | Ndiff    0.000
# ... done. converged.
# Training "blocked" model L = 2
# Learn Alg: VB | task  3/1 | alg. seed: 6168832 | data order seed: 7360256
# task_output_path: experiments/mocap-newargs
# Learn Alg: VB | task  3/1 | alg. seed: 6168832 | data order seed: 7360256
# task_output_path: experiments/mocap-newargs/blocked-L=4/3
#         1/500 after      0 sec. |    205.4 MiB | K   20 | loss  2.707747109e+00 |
#         2/500 after      0 sec. |    205.1 MiB | K   20 | loss  2.468093614e+00 | Ndiff   82.639
#        25/500 after      6 sec. |    205.1 MiB | K   20 | loss  2.211978343e+00 | Ndiff    1.408
#        50/500 after     11 sec. |    205.3 MiB | K   20 | loss  2.209694320e+00 | Ndiff    0.054
#        75/500 after     17 sec. |    205.3 MiB | K   20 | loss  2.206399659e+00 | Ndiff    1.700
#        87/500 after     19 sec. |    205.3 MiB | K   20 | loss  2.206282748e+00 | Ndiff    0.000
# ... done. converged.
# Training sparse model L = 5
# Learn Alg: VB | task  3/1 | alg. seed: 6168832 | data order seed: 7360256
# task_output_path: experiments/mocap-newargs/sparse-L=5/3
#         1/500 after      0 sec. |    212.5 MiB | K   20 | loss  2.707747109e+00 |
#         2/500 after      0 sec. |    212.3 MiB | K   20 | loss  2.468299830e+00 | Ndiff   82.098
#        25/500 after      5 sec. |    212.3 MiB | K   20 | loss  2.212140431e+00 | Ndiff    1.110
#        50/500 after     11 sec. |    212.3 MiB | K   20 | loss  2.210232627e+00 | Ndiff    0.051
#        75/500 after     16 sec. |    212.3 MiB | K   20 | loss  2.206983589e+00 | Ndiff    1.807
#        91/500 after     19 sec. |    212.3 MiB | K   20 | loss  2.206821263e+00 | Ndiff    0.000
# ... done. converged.
# Training O(L^2) model L = 5
# Learn Alg: VB | task  3/1 | alg. seed: 6168832 | data order seed: 7360256
# task_output_path: experiments/mocap-newargs/OL2-L=5/3
#         1/500 after      0 sec. |    219.4 MiB | K   20 | loss  2.707747109e+00 |
#         2/500 after      0 sec. |    219.2 MiB | K   20 | loss  2.467934115e+00 | Ndiff   82.636
#        25/500 after      6 sec. |    219.3 MiB | K   20 | loss  2.212185155e+00 | Ndiff    0.908
#        50/500 after     11 sec. |    219.4 MiB | K   20 | loss  2.204025357e+00 | Ndiff    0.001
#        54/500 after     12 sec. |    219.5 MiB | K   20 | loss  2.204025357e+00 | Ndiff    0.000
# ... done. converged.
# Training "blocked" model L = 5
# Learn Alg: VB | task  3/1 | alg. seed: 6168832 | data order seed: 7360256
# task_output_path: experiments/mocap-newargs/blocked-L=5/3
#         1/500 after      0 sec. |    226.8 MiB | K   20 | loss  2.707747109e+00 |
#         2/500 after      0 sec. |    226.6 MiB | K   20 | loss  2.468309926e+00 | Ndiff   82.492
#        25/500 after      6 sec. |    226.7 MiB | K   20 | loss  2.211190317e+00 | Ndiff    1.004
#        50/500 after     12 sec. |    226.7 MiB | K   20 | loss  2.209443394e+00 | Ndiff    0.042
#        75/500 after     18 sec. |    226.7 MiB | K   20 | loss  2.207772785e+00 | Ndiff    1.381
#        87/500 after     20 sec. |    226.7 MiB | K   20 | loss  2.206136977e+00 | Ndiff    0.000
# ... done. converged.

# %% [markdown]
# # Plot results

# %%
# Load results if necessary
try:
    experiment
except NameError:
    experiment = util.load_experiment(out_path)

# %%
util.plot_loss(experiment, dataset_title, ymax=2.45)

# %%
util.plot_hamming(experiment, dataset_title)

# %%
len(dataset.TrueParams['Z'])
# Out:
# 2058

# %%
import os
dataset_path = os.path.join(bnpy.DATASET_PATH, 'mocap6')
dataset1 = bnpy.data.GroupXData.read_npz(
    os.path.join(dataset_path, 'dataset.npz'))

# %%
len(dataset.TrueParams['Z'])
# Out:
# 2058

# %%
len(dataset.X)
# Out:
# 2058
